# %% [markdown]
# # **Using Topic Modelling and LDA for Extractive Summarization of Legal Documents**

# %%
import gensim
import json
import math
import nltk
import pprint
from gensim import corpora, models
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from google.colab import drive
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
from functools import reduce
from termcolor import colored
from scipy import spatial

drive.mount('/content/drive', force_remount=True)
FILE_PATH = "/content/drive/My Drive/Colab Notebooks/topic_modelling_data/"
FILE_NAME = "drug_labeled_20190926.json"  
FILE = open(FILE_PATH + FILE_NAME, encoding='utf8')
DATA = json.load(FILE)
all_data = list(map(lambda x: {"annotation": x["annotation"], "content": x["content"]}, DATA["data"]))

nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')
# Out:
# Mounted at /content/drive
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/omw-1.4.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## Function to filter and pre-process data entries (called passages), one at a time

# %%
label_to_data = {
    # Offences
    "offence_type_quant_of_drugs": ["OT", "OQ", "OQT"],
    "offence_motive": ["OM"],
    "offence_role": ["ORC", "ORM", "ORO", "ORF"],

    # Aggravating factors
    "aggravating_factors_commited_while_bail": ["ABC"],
    "aggravating_factors_persistence": ["APC"],
    "aggravating_factors_international": ["AIC"],
    "aggravating_factors_other": ["AXC"],

    # Mitigating factors
    "mitigating_factors_remorse": ["MRC"],
    "mitigating_factors_self_consumption": ["MSC"],
    "mitigating_factors_assist_authorities": ["MCC", "MYC"],
    "mitigating_factors_characters_others": ["MGC", "MXC"],

    # Background
    "background_relationship_family": ["BR", "BI"],
    "background_criminal_drug_record": ["BP", "BL", "BD"],
    "background_personality": ["BN"],
    "background_health": ["BH"],
    "background_experience": ["BE", "BO"]
}

num_topics = {
    # # Offences
    # "offence_type_quant_of_drugs": 1,
    # "offence_motive": 1,
    # "offence_role": 1,

    # # Aggravating factors
    # "aggravating_factors_commited_while_bail": 1,
    # "aggravating_factors_persistence": 1,
    # "aggravating_factors_international": 1,
    # "aggravating_factors_other": 1,

    # # Mitigating factors


    # # Background
    # "background_relationship_family": 5 
}

def label_starts_with_matches(label: str):
  for key in label_to_data:
    for key_label in label_to_data[key]:
      if key_label == label[:len(key_label)].upper():
        return key
  return None

selected = {}

for label in label_to_data:
  selected[label] = []
  num_topics[label] = 1       # set all models to only have 1 topic for now

stopwords = list(gensim.parsing.preprocessing.STOPWORDS) + ['whilst', 'hong', 'kong', 'drug', 'drugs', 'section', 'offence', 'defendant', 'ordinance', 'dangerous', 'trafficking']

# stem, lemmatize, todo: filter stopwords/common words + reduce to one piece of string(?)
def preprocess(passage):
  stemmer = SnowballStemmer('english')
  return list(filter(
              lambda word: word not in stopwords and len(word) >= 3,
              gensim.utils.simple_preprocess(passage)
         ))
        #       list(map(
        #           lambda word: stemmer.stem(WordNetLemmatizer().lemmatize(word, pos='v')),
        #           gensim.utils.simple_preprocess(passage)
        #       ))
        #  ))

def select_data(json_data: dict):
  for annotation in json_data['annotation']:
    for label in annotation['label']:
      result = label_starts_with_matches(label)
      if result is not None:
        for point in annotation['points']:
          selected[result].append(preprocess(point['text']))

# %% [markdown]
# ## Visualizing data entries

# %%
pp = pprint.PrettyPrinter(indent=2)
pp.pprint(all_data[3126])
# Out:
# { 'annotation': [ { 'label': ['PIC1D1_INDIVIDUAL_PENALTY_charge1_defendant1'],
#                     'points': [ { 'end': 7433,
#                                   'start': 7414,
#                                   'text': '4 years and 8 months'}]},
#                   { 'label': ['PSC1D1_PLEA_SENTENCE_charge1_defendant1'],
#                     'points': [ { 'end': 7347,
#                                   'start': 7339,
#                                   'text': 'one-third'}]},
#                   { 'label': ['SPC1D1_STARTING_TARIFF_charge1_defendant1'],
#                     'points': [ { 'end': 7309,
#                                   'start': 7303,
#                                   'text': '7 years'}]},
#                   { 'label': ['BID1_FAMILY_defendant1'],
#                     'points': [ { 'end': 6787,
#                                   'start': 6737,
#                                   'text': 'she does have a\n'
#                                           'close bond with her adult '
#                                           'daughter.'}]},
#                   { 'label': ['CC_CASE_CITED'],
#                     'points': [ { 'end': 6517,
#                                   'start': 6479,
#                                   'text': 'HKSAR v Chan\n'
#                                           'Pui Chi [1999] 2 HKLRD 830'}]},
#                   { 'label': ['BPD1_PREVIOUS_CRIMINAL_defendant1'],
#                     'points': [ { 'end': 6038,
#                                   'start': 5085,
#                                   'text': 'She has a criminal record dating '
#                                           'back to 1989, when she would have '
#                                           'been only\n'
#                                           '18 years of age. She was then '
#                                           'convicted and fined for possession '
#                                           'of dangerous\n'
#                                           'drugs. Then in 1993 she was '
#                                           'convicted of robbery and sentenced '
#                                           'to 12 months’\n'
#                                           'imprisonment. At around the same '
#                                           'time, she was convicted of a '
#                                           'further two\n'
#                                           'charges of possession of dangerous '
#                                           'drugs. In 1994 she was convicted in '
#                                           'the\n'
#                                           'High Court of 3 counts of '
#                                           'trafficking in drugs, and sentenced '
#                                           'to a total of 10\n'
#                                           'years’ imprisonment.\n'
#                                           '\n'
#                                           '>\n'
#                                           '\n'
#                                           '> After her release from prison she '
#                                           'has continued to be involved with\n'
#                                           'dangerous drugs. She was convicted '
#                                           'in 2002 of possession of dangerous '
#                                           'drugs,\n'
#                                           'and in 2005 of trafficking in '
#                                           'dangerous drugs. For the '
#                                           'trafficking offence she\n'
#                                           'was sentenced to 13 months’ '
#                                           'imprisonment. She then had '
#                                           'convictions in 2007 for\n'
#                                           'theft and possession of dangerous '
#                                           'drugs, and mostly recently in 2008 '
#                                           'for\n'
#                                           'trafficking in dangerous drugs, '
#                                           'when she was again sent to prison, '
#                                           'this time\n'
#                                           'for 16 months.'}]},
#                   { 'label': ['addictive', 'BDD1_DRUG_ADDICT_defendant1'],
#                     'points': [ { 'end': 5077,
#                                   'start': 5014,
#                                   'text': 'She claims to have been addicted to '
#                                           '“Ice” for the\n'
#                                           'past 10 years.'}]},
#                   { 'label': ['BRD1_RELATIONSHIP_defendant1'],
#                     'points': [ { 'end': 5012,
#                                   'start': 4982,
#                                   'text': 'She is\nsingle, and lived alone.'}]},
#                   { 'label': ['BOD1_OCCUPATION_defendant1'],
#                     'points': [ { 'end': 4980,
#                                   'start': 4936,
#                                   'text': 'She was unemployed at the time of '
#                                           'her arrest.'}]},
#                   { 'label': ['BED1_EDUCATION_defendant1'],
#                     'points': [ { 'end': 4933,
#                                   'start': 4912,
#                                   'text': 'secondary Form 1 level'}]},
#                   { 'label': ['BSD1_SENTENCING_AGE_defendant1'],
#                     'points': [{'end': 4859, 'start': 4858, 'text': '40'}]},
#                   { 'label': ['CC_CASE_CITED'],
#                     'points': [ { 'end': 4832,
#                                   'start': 4793,
#                                   'text': 'HKSAR v Chong Heung Sang\n'
#                                           '[2010] 3 HKC 88'}]},
#                   { 'label': ['CC_CASE_CITED'],
#                     'points': [ { 'end': 4787,
#                                   'start': 4753,
#                                   'text': 'HKSAR v Abdallah [2009] 2 HKLRD '
#                                           '437'}]},
#                   { 'label': ['CC_CASE_CITED'],
#                     'points': [ { 'end': 4080,
#                                   'start': 4028,
#                                   'text': 'Secretary for Justice v Chan Ka Wah '
#                                           '[2005] 4 HKLR 904'}]},
#                   { 'label': ['CC_CASE_CITED'],
#                     'points': [ { 'end': 3789,
#                                   'start': 3757,
#                                   'text': 'HKSAR v Manalo [2001] 1 HKLRD '
#                                           '557'}]},
#                   { 'label': ['CGC1D1_GUIDELINE_charge1_defendant1'],
#                     'points': [ { 'end': 3268,
#                                   'start': 2694,
#                                   'text': 'The first is that the sentencing '
#                                           'ranges for trafficking in “Ice” are '
#                                           'to be\n'
#                                           'taken from the guidelines laid down '
#                                           'by the Court of Appeal in '
#                                           'Attorney-General\n'
#                                           'and Ching Kwok Hung [1991] 2 HKLRD '
#                                           '125as amended by the Court of '
#                                           'Appeal in the\n'
#                                           'subsequent decision of HKSAR v '
#                                           'Capitania CACC28/2004. As a result '
#                                           'of this\n'
#                                           'subsequent amendment the first '
#                                           'sentencing band relates to '
#                                           'quantities up to 10\n'
#                                           'grammes and so in the present case, '
#                                           'as the quantity in which this '
#                                           'defendant\n'
#                                           'trafficked was 10.90 grammes of '
#                                           '“Ice”, this defendant is placed in '
#                                           'the 7 to 10\n'
#                                           'years band for sentencing '
#                                           'purposes.'}]},
#                   { 'label': ['OVC1_VALUE_DRUGS_charge1'],
#                     'points': [{'end': 2475, 'start': 2470, 'text': '$7,820'}]},
#                   { 'label': ['ODC1_DATE_OF_OFFENCE_charge1'],
#                     'points': [ { 'end': 941,
#                                   'start': 931,
#                                   'text': '4 July 2011'}]},
#                   { 'label': ['OTC1_TYPE_DRUGS_charge1'],
#                     'points': [ { 'end': 901,
#                                   'start': 873,
#                                   'text': 'methamphetamine hydrochloride'}]},
#                   { 'label': ['OQC1_QUANTITY_DRUGS_charge1'],
#                     'points': [ { 'end': 868,
#                                   'start': 856,
#                                   'text': '10.90 grammes'}]},
#                   { 'label': ['PH0C1D1_PLEA_HC_UNKNOWN_charge1_defendant1'],
#                     'points': [ { 'end': 800,
#                                   'start': 734,
#                                   'text': 'The defendant has pleaded guilty to '
#                                           'trafficking in a dangerous drug'}]},
#                   { 'label': ['OCC1D1_CHARGE1_defendant1'],
#                     'points': [ { 'end': 577,
#                                   'start': 536,
#                                   'text': 'Trafficking in a dangerous drug '
#                                           '(販運危險藥物)  '}]},
#                   { 'label': ['BFD1_FEMALE_defendant1'],
#                     'points': [ { 'end': 261,
#                                   'start': 248,
#                                   'text': 'Kwok Kam-fung '}]},
#                   { 'label': ['NC_NEUTRAL_CITATION'],
#                     'points': [ { 'end': 42,
#                                   'start': 27,
#                                   'text': '[2012] HKCFI 376'}]}],
#   'content': '##  HKSAR v. KWOK KAM FUNG [2012] HKCFI 376; HCCC 464/2011 (16 '
#              'February 2012)\n'
#              '\n'
#              'HCCC464/2011\n'
#              '\n'
#              'IN THE HIGH COURT OF THE\n'
#              '\n'
#              'HONG KONG SPECIAL ADMINISTRATIVE REGION\n'
#              '\n'
#              'COURT OF FIRST INSTANCE\n'
#              '\n'
#              'CRIMINAL CASE NO. 464 OF 2011\n'
#              '\n'
#              '\\-----------------\n'
#              '\n'
#              'HKSAR  \n'
#              'v  \n'
#              'Kwok Kam-fung  \n'
#              '  \n'
#              '\\-----------------\n'
#              '\n'
#              'Before:  Hon McWalters J  \n'
#              'Date:  16 February 2012 at 9.52 am  \n'
#              'Present:  Ms Grace Chan, SPP of the Department of Justice, for '
#              'HKSAR  \n'
#              'Miss Anita Ma, instructed by Godwin Chan & Co, assigned by the '
#              'Director of\n'
#              'Legal Aid, for the Accused  \n'
#              'Offence:  Trafficking in a dangerous drug (販運危險藥物)  \n'
#              '  \n'
#              '\\---------------------------------\n'
#              '\n'
#              'Transcript of the Audio Recording  \n'
#              'of the Sentence in the above Case\n'
#              '\n'
#              '> \\---------------------------------\n'
#              '\n'
#              'COURT: The defendant has pleaded guilty to trafficking in a '
#              'dangerous drug,\n'
#              'namely 11.14 grammes of crystalline solid containing 10.90 '
#              'grammes of\n'
#              'methamphetamine hydrochloride.\n'
#              '\n'
#              '> At around 1850 hours on 4 July 2011, police officers on duty '
#              'outside Flat\n'
#              'F2, 16th Floor, Kingland Apartments, No. 737‑741C Nathan Road, '
#              'Mong Kok,\n'
#              'observed the defendant exiting from this flat in a furtive '
#              'manner. When the\n'
#              'police started to approach the defendant to make inquiry of her, '
#              'she\n'
#              'immediately tried to return to her flat. One of the officers '
#              'revealed his\n'
#              'identity and then executed a search warrant of the premises.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> At around 1905 hours, when the police started to conduct the '
#              'house search,\n'
#              'the defendant told a police officer that the dangerous drugs and '
#              'packaging\n'
#              'paraphernalia were kept inside a drawer of a white cabinet near '
#              'the\n'
#              'refrigerator. Inside this drawer the police officer seized a '
#              'number of items,\n'
#              'amongst which were:\n'
#              '\n'
#              '>\n'
#              '\n'
#              '>> (a) eight plastic bags containing the “Ice” that is the '
#              'subject of the\n'
#              'charge;\n'
#              '\n'
#              '>>\n'
#              '\n'
#              '>> (b) one bundle of empty resealable transparent plastic bags;\n'
#              '\n'
#              '>>\n'
#              '\n'
#              '>> (c) one electronic scale; and\n'
#              '\n'
#              '>>\n'
#              '\n'
#              '>> (d) one pair of scissors.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> Between 2356 hours on 4 July 2011 and 0700 hours on 5 July '
#              '2011, the\n'
#              'defendant was interviewed on video. Under caution she admitted '
#              'the following:\n'
#              '\n'
#              '>\n'
#              '\n'
#              '>> (a) the “Ice” seized was for sale;\n'
#              '\n'
#              '>>\n'
#              '\n'
#              '>> (b) the packaging paraphernalia was for packing the “Ice”; '
#              'and\n'
#              '\n'
#              '>>\n'
#              '\n'
#              '>> (c) she rented the flat.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> The Government Chemist certified that the eight bags of “Ice” '
#              'were 11.14\n'
#              'grammes of a crystalline solid containing 10.90 grammes of '
#              'methamphetamine\n'
#              'hydrochloride, a salt of methamphetamine.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> The total retail value of the drugs seized is estimated by a '
#              'police drug\n'
#              'expert to be $7,820.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> In a number of different cases the Hong Kong Court of Appeal '
#              'has set out the\n'
#              'principles and sentencing guidelines for judges to follow when '
#              'sentencing a\n'
#              'defendant convicted of a drug trafficking offence.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> The first is that the sentencing ranges for trafficking in '
#              '“Ice” are to be\n'
#              'taken from the guidelines laid down by the Court of Appeal in '
#              'Attorney-General\n'
#              'and Ching Kwok Hung [1991] 2 HKLRD 125as amended by the Court of '
#              'Appeal in the\n'
#              'subsequent decision of HKSAR v Capitania CACC28/2004. As a '
#              'result of this\n'
#              'subsequent amendment the first sentencing band relates to '
#              'quantities up to 10\n'
#              'grammes and so in the present case, as the quantity in which '
#              'this defendant\n'
#              'trafficked was 10.90 grammes of “Ice”, this defendant is placed '
#              'in the 7 to 10\n'
#              'years band for sentencing purposes.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> The existence of these sentencing tariffs leaves little room '
#              'for mitigation,\n'
#              'but notwithstanding this, the sentencing tariffs play a very '
#              'important role\n'
#              'for two main reasons. Firstly, they lead to consistency in '
#              'sentencing and\n'
#              'avoid distinctions being drawn between drug traffickers based '
#              'upon the nature\n'
#              'of their trafficking, whether they be couriers, storekeepers, or '
#              'play some\n'
#              'other role. Whatever the role played by the trafficker, the '
#              'sentence will\n'
#              'generally be the same. See HKSAR v Manalo [2001] 1 HKLRD 557 at '
#              '560 G-H.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> The purpose of these sentencing bands is to lead to '
#              'consistency in\n'
#              'sentencing, and secondly, to deter those who might otherwise be '
#              'tempted by\n'
#              'what they perceive as an easy and low‑risk means to substantial '
#              'profits. See\n'
#              'Secretary for Justice v Chan Ka Wah [2005] 4 HKLR 904 at 908, '
#              'paragraph 20.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> The Court of Appeal has made it clear that it requires '
#              'exceptional\n'
#              'circumstances to justify a departure from the guidelines, and '
#              'that whilst a\n'
#              'sentencing judge may retain some degree of discretion, the '
#              'sentence imposed\n'
#              'should normally be within the suggested bands. See the Chan Ka '
#              'Wah case at\n'
#              'page 908, paragraph 22.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> No such circumstances are present in this case. Nevertheless, '
#              'I still have\n'
#              'some sentencing discretion, and I can take into account the '
#              'amount of packets,\n'
#              'the type of mixture containing the narcotic, the degree of the '
#              'involvement of\n'
#              'the offender and any previous involvement he or she may have had '
#              'in drug\n'
#              'offences. See HKSAR v Abdallah [2009] 2 HKLRD 437 and HKSAR v '
#              'Chong Heung Sang\n'
#              '[2010] 3 HKC 88.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> The defendant is 40 years of age and has received education '
#              'only up to\n'
#              'secondary Form 1 level. She was unemployed at the time of her '
#              'arrest. She is\n'
#              'single, and lived alone. She claims to have been addicted to '
#              '“Ice” for the\n'
#              'past 10 years.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> She has a criminal record dating back to 1989, when she would '
#              'have been only\n'
#              '18 years of age. She was then convicted and fined for possession '
#              'of dangerous\n'
#              'drugs. Then in 1993 she was convicted of robbery and sentenced '
#              'to 12 months’\n'
#              'imprisonment. At around the same time, she was convicted of a '
#              'further two\n'
#              'charges of possession of dangerous drugs. In 1994 she was '
#              'convicted in the\n'
#              'High Court of 3 counts of trafficking in drugs, and sentenced to '
#              'a total of 10\n'
#              'years’ imprisonment.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> After her release from prison she has continued to be involved '
#              'with\n'
#              'dangerous drugs. She was convicted in 2002 of possession of '
#              'dangerous drugs,\n'
#              'and in 2005 of trafficking in dangerous drugs. For the '
#              'trafficking offence she\n'
#              'was sentenced to 13 months’ imprisonment. She then had '
#              'convictions in 2007 for\n'
#              'theft and possession of dangerous drugs, and mostly recently in '
#              '2008 for\n'
#              'trafficking in dangerous drugs, when she was again sent to '
#              'prison, this time\n'
#              'for 16 months.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> In identifying appropriate penalties when assessing an '
#              'appropriate starting\n'
#              'point, I cannot ignore the defendant’s criminal record. Her past '
#              'offending\n'
#              'reveals a failure to be deterred by the criminal justice process '
#              'from\n'
#              'reoffending. This failure to be deterred, this persistent '
#              'reoffending, and\n'
#              'this continued involvement in drug trafficking constitutes an '
#              'aggravating\n'
#              'factor justifying the adoption of a higher starting point. See '
#              'HKSAR v Chan\n'
#              'Pui Chi [1999] 2 HKLRD 830.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> However, her counsel asks for one last chance for her client. '
#              'Amongst all\n'
#              'the gloom, she points to a glimmer of hope in that the defendant '
#              'did at one\n'
#              'stage prior to these offences engage in some employment, and she '
#              'does have a\n'
#              'close bond with her adult daughter. These two factors may '
#              'provide some hope\n'
#              'that the defendant will try and break the cycle of drug '
#              'addiction and drug\n'
#              'trafficking which has dogged her life.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> In the present case, the quantity of drugs is 10.90 grammes, '
#              'just above the\n'
#              '10 grammes lower limit of the sentencing band. I have decided to '
#              'extend to the\n'
#              'defendant the last chance and the leniency that has been asked, '
#              'and instead of\n'
#              'increasing the starting point within this band, I will adopt the '
#              'lower limit\n'
#              'of the band as my starting point. That is, 7 years. I discount '
#              'her sentence by\n'
#              'one-third to allow for her plea of guilty.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> The resulting sentence is 4 years and 8 months, and that is '
#              'the sentence I\n'
#              'impose.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> Miss Kwok, your case is one which is of great concern to me '
#              'and which\n'
#              'disturbs me greatly. You have wasted your youth, and the only '
#              'issue that\n'
#              'remains is whether you can make something of the life that is '
#              'left to you.\n'
#              'Your life has been a cycle of drug addiction and drug '
#              'trafficking interrupted\n'
#              'by periods in prison because of these addictions. I fully '
#              'appreciate that you\n'
#              'may find drug trafficking an easy means of sourcing an income, '
#              'since you do\n'
#              'not have qualifications which would enable you to get a '
#              'highly-paid job.\n'
#              'However, you should be well aware that continued involvement in '
#              'drug\n'
#              'trafficking can only lead to further periods of imprisonment and '
#              'the\n'
#              'destruction of your life.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> You are very fortunate indeed that you still have some '
#              'closeness with your\n'
#              'daughter. If you want to enjoy that relationship, then try and '
#              'do something to\n'
#              'break the cycle of drug addiction and drug trafficking. You will '
#              'be well aware\n'
#              'that the Commissioner for Correctional Services has the power to '
#              'reduce your\n'
#              'sentence further by remitting part of it should you be of good '
#              'behaviour. You\n'
#              'will also be aware of what facilities exist in prison that might '
#              'enable you to\n'
#              'acquire some kind of skill or qualification that you can make '
#              'use of on your\n'
#              'release.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> What you do with your life after your release is entirely in '
#              'your hands. You\n'
#              'are fortunate indeed that I have not started at a higher '
#              'starting point than\n'
#              'the one I adopted. You can be confident that courts in future '
#              'will not extend\n'
#              'you any leniency should you appear again on drug‑trafficking '
#              'charges.\n'
#              '\n'
#              '>\n'
#              '\n'
#              '> Prison provides you with an opportunity to try and break away '
#              'from drug\n'
#              'trafficking and acquire a skill. I urge you to take advantage of '
#              'that\n'
#              'opportunity, otherwise you will find yourself regularly '
#              'appearing in court and\n'
#              'regularly being sent to prison.'}

# %% [markdown]
# ## Training the Word2Vec Model

# %%
punctuation = [",", ".", ":", ">"]

all_sentences = []

for data in all_data:
  content = data['content']
  all_sentences += list(filter(
    lambda w: w not in punctuation and w != "",
    list(map(
        lambda sentence: gensim.utils.simple_preprocess(sentence),
        nltk.tokenize.sent_tokenize(content.replace(">", "").lower())
    ))
  ))
  
word2vec_model = gensim.models.Word2Vec(all_sentences, min_count=4)

# %% [markdown]
# ## Feeding Data to the topic model

# %%
class TopicModel:
  def __init__(self, aspect_name, passages, num_topics=4, no_below=6, no_above=0.6):
    self.aspect_name = aspect_name

    self.dictionary = corpora.Dictionary(passages)
    self.dictionary.filter_extremes(no_below=no_below, no_above=no_above)

    bow_corpus = [self.dictionary.doc2bow(passage) for passage in passages]

    tfidf = models.TfidfModel(bow_corpus)
    corpus_tfidf = tfidf[bow_corpus]

    self.lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=num_topics,
                                                id2word=self.dictionary, passes=2,
                                                workers=2)

  def __str__(self):
    result = ""
    for idx, topic in self.lda_model.print_topics(-1):
      result += f"Topic: {idx}\nWords: {topic}\n"
    return result

  def similarity(self, sentence):
    return self.lda_model.get_document_topics(self.dictionary.doc2bow(sentence))
  

def get_lda_models():

  for data in all_data:
    select_data(data)

  lda_models = {}

  for aspect in selected:
    print("ASPECT", aspect.upper())

    lda_models[aspect] = TopicModel(aspect, selected[aspect], num_topics[aspect])

    print(lda_models[aspect])
  
  return lda_models

# %%
lda_models = get_lda_models()
# Out:
# ASPECT OFFENCE_TYPE_QUANT_OF_DRUGS
# Topic: 0
# Words: 0.373*"grammes" + 0.142*"ketamine" + 0.129*"hydrochloride" + 0.098*"cocaine" + 0.075*"methamphetamine" + 0.061*"heroin" + 0.023*"kilogrammes" + 0.022*"ice" + 0.012*"kilogramme" + 0.010*"cannabis"
#
# ASPECT OFFENCE_MOTIVE
# Topic: 0
# Words: 0.089*"money" + 0.061*"financial" + 0.031*"earn" + 0.029*"committed" + 0.025*"quick" + 0.022*"debt" + 0.021*"family" + 0.019*"present" + 0.014*"support" + 0.012*"pressure"
#
# ASPECT OFFENCE_ROLE
# Topic: 0
# Words: 0.056*"reward" + 0.046*"deliver" + 0.033*"courier" + 0.025*"delivering" + 0.024*"ketamine" + 0.022*"admitted" + 0.017*"delivery" + 0.016*"sell" + 0.016*"person" + 0.016*"said"
#
# ASPECT AGGRAVATING_FACTORS_COMMITED_WHILE_BAIL
# Topic: 0
# Words: 0.384*"present" + 0.247*"police" + 0.164*"case" + 0.110*"court" + 0.096*"offences"
#
# ASPECT AGGRAVATING_FACTORS_PERSISTENCE
# Topic: 0
# Words: 0.093*"previous" + 0.073*"record" + 0.073*"conviction" + 0.060*"offender" + 0.048*"convicted" + 0.045*"months" + 0.043*"committed" + 0.039*"convictions" + 0.037*"prison" + 0.035*"repeated"
#
# ASPECT AGGRAVATING_FACTORS_INTERNATIONAL
# Topic: 0
# Words: 0.120*"international" + 0.068*"element" + 0.044*"airport" + 0.036*"arrived" + 0.034*"border" + 0.032*"imported" + 0.030*"mainland" + 0.024*"flight" + 0.022*"customs" + 0.021*"china"
#
# ASPECT AGGRAVATING_FACTORS_OTHER
# Topic: 0
# Words: 0.080*"risk" + 0.076*"latent" + 0.057*"types" + 0.057*"different" + 0.053*"aggravating" + 0.049*"cocaine" + 0.049*"minor" + 0.049*"factor" + 0.046*"ice" + 0.038*"cocktail"
#
# ASPECT MITIGATING_FACTORS_REMORSE
# Topic: 0
# Words: 0.457*"remorse" + 0.292*"remorseful" + 0.036*"guilty" + 0.031*"accept" + 0.027*"plea" + 0.022*"police" + 0.020*"court" + 0.020*"truly" + 0.018*"expresses" + 0.016*"clear"
#
# ASPECT MITIGATING_FACTORS_SELF_CONSUMPTION
# Topic: 0
# Words: 0.218*"self" + 0.082*"accept" + 0.055*"small" + 0.051*"use" + 0.040*"intended" + 0.038*"prepared" + 0.031*"proportion" + 0.031*"consumed" + 0.030*"portion" + 0.030*"ice"
#
# ASPECT MITIGATING_FACTORS_ASSIST_AUTHORITIES
# Topic: 0
# Words: 0.155*"delivery" + 0.152*"controlled" + 0.069*"evidence" + 0.053*"assistance" + 0.053*"operation" + 0.048*"prosecution" + 0.042*"authorities" + 0.042*"given" + 0.035*"gave" + 0.035*"police"
#
# ASPECT MITIGATING_FACTORS_CHARACTERS_OTHERS
# Topic: 0
# Words: 0.045*"police" + 0.042*"record" + 0.038*"clear" + 0.032*"young" + 0.032*"age" + 0.031*"good" + 0.026*"family" + 0.024*"character" + 0.023*"father" + 0.018*"circumstances"
#
# ASPECT BACKGROUND_RELATIONSHIP_FAMILY
# Topic: 0
# Words: 0.050*"mother" + 0.034*"family" + 0.033*"father" + 0.032*"parents" + 0.032*"single" + 0.030*"married" + 0.022*"son" + 0.021*"old" + 0.020*"wife" + 0.020*"aged"
#
# ASPECT BACKGROUND_CRIMINAL_DRUG_RECORD
# Topic: 0
# Words: 0.067*"previous" + 0.058*"convictions" + 0.056*"record" + 0.044*"possession" + 0.036*"clear" + 0.033*"conviction" + 0.029*"sentenced" + 0.027*"criminal" + 0.023*"months" + 0.020*"imprisonment"
#
# ASPECT BACKGROUND_PERSONALITY
# Topic: 0
# Words: 0.141*"good" + 0.107*"person" + 0.097*"naïve" + 0.063*"caring" + 0.058*"character" + 0.053*"foolish" + 0.053*"filial" + 0.049*"responsible" + 0.044*"stupidity" + 0.044*"hardworking"
#
# ASPECT BACKGROUND_HEALTH
# Topic: 0
# Words: 0.080*"health" + 0.051*"medical" + 0.040*"suffered" + 0.038*"suffering" + 0.035*"treatment" + 0.035*"problems" + 0.035*"good" + 0.032*"condition" + 0.031*"problem" + 0.023*"psychiatric"
#
# ASPECT BACKGROUND_EXPERIENCE
# Topic: 0
# Words: 0.134*"form" + 0.096*"unemployed" + 0.069*"worker" + 0.056*"level" + 0.048*"education" + 0.035*"secondary" + 0.027*"time" + 0.027*"educated" + 0.022*"school" + 0.018*"transportation"

# %% [markdown]
# # Testing Topic Model on an Example

# %%
test = "The defendant has pleaded guilty to trafficking in a dangerous drug, namely 11.14 grammes of crystalline solid containing 10.90 grammes of\nmethamphetamine hydrochloride.\n\n> At around 1850 hours on 4 July 2011, police officers on duty outside Flat\nF2, 16th Floor, Kingland Apartments, No. 737\u2011741C Nathan Road, Mong Kok,\nobserved the defendant exiting from this flat in a furtive manner. When the\npolice started to approach the defendant to make inquiry of her, she\nimmediately tried to return to her flat. One of the officers revealed his\nidentity and then executed a search warrant of the premises.\n\n>\n\n> At around 1905 hours, when the police started to conduct the house search,\nthe defendant told a police officer that the dangerous drugs and packaging\nparaphernalia were kept inside a drawer of a white cabinet near the\nrefrigerator. Inside this drawer the police officer seized a number of items,\namongst which were:\n\n>\n\n>> (a) eight plastic bags containing the \u201cIce\u201d that is the subject of the\ncharge;\n\n>>\n\n>> (b) one bundle of empty resealable transparent plastic bags;\n\n>>\n\n>> (c) one electronic scale; and\n\n>>\n\n>> (d) one pair of scissors.\n\n>\n\n> Between 2356 hours on 4 July 2011 and 0700 hours on 5 July 2011, the\ndefendant was interviewed on video. Under caution she admitted the following:\n\n>\n\n>> (a) the \u201cIce\u201d seized was for sale;\n\n>>\n\n>> (b) the packaging paraphernalia was for packing the \u201cIce\u201d; and\n\n>>\n\n>> (c) she rented the flat.\n\n>\n\n> The Government Chemist certified that the eight bags of \u201cIce\u201d were 11.14\ngrammes of a crystalline solid containing 10.90 grammes of methamphetamine\nhydrochloride, a salt of methamphetamine.\n\n>\n\n> The total retail value of the drugs seized is estimated by a police drug\nexpert to be $7,820.\n\n>\n\n> In a number of different cases the Hong Kong Court of Appeal has set out the\nprinciples and sentencing guidelines for judges to follow when sentencing a\ndefendant convicted of a drug trafficking offence.\n\n>\n\n> The first is that the sentencing ranges for trafficking in \u201cIce\u201d are to be\ntaken from the guidelines laid down by the Court of Appeal in Attorney-General\nand Ching Kwok Hung [1991] 2 HKLRD 125as amended by the Court of Appeal in the\nsubsequent decision of HKSAR v Capitania CACC28/2004. As a result of this\nsubsequent amendment the first sentencing band relates to quantities up to 10\ngrammes and so in the present case, as the quantity in which this defendant\ntrafficked was 10.90 grammes of \u201cIce\u201d, this defendant is placed in the 7 to 10\nyears band for sentencing purposes.\n\n>\n\n> The existence of these sentencing tariffs leaves little room for mitigation,\nbut notwithstanding this, the sentencing tariffs play a very important role\nfor two main reasons. Firstly, they lead to consistency in sentencing and\navoid distinctions being drawn between drug traffickers based upon the nature\nof their trafficking, whether they be couriers, storekeepers, or play some\nother role. Whatever the role played by the trafficker, the sentence will\ngenerally be the same. See HKSAR v Manalo [2001] 1 HKLRD 557 at 560 G-H.\n\n>\n\n> The purpose of these sentencing bands is to lead to consistency in\nsentencing, and secondly, to deter those who might otherwise be tempted by\nwhat they perceive as an easy and low\u2011risk means to substantial profits. See\nSecretary for Justice v Chan Ka Wah [2005] 4 HKLR 904 at 908, paragraph 20.\n\n>\n\n> The Court of Appeal has made it clear that it requires exceptional\ncircumstances to justify a departure from the guidelines, and that whilst a\nsentencing judge may retain some degree of discretion, the sentence imposed\nshould normally be within the suggested bands. See the Chan Ka Wah case at\npage 908, paragraph 22.\n\n>\n\n> No such circumstances are present in this case. Nevertheless, I still have\nsome sentencing discretion, and I can take into account the amount of packets,\nthe type of mixture containing the narcotic, the degree of the involvement of\nthe offender and any previous involvement he or she may have had in drug\noffences. See HKSAR v Abdallah [2009] 2 HKLRD 437 and HKSAR v Chong Heung Sang\n[2010] 3 HKC 88.\n\n>\n\n> The defendant is 40 years of age and has received education only up to\nsecondary Form 1 level. She was unemployed at the time of her arrest. She is\nsingle, and lived alone. She claims to have been addicted to \u201cIce\u201d for the\npast 10 years.\n\n>\n\n> She has a criminal record dating back to 1989, when she would have been only\n18 years of age. She was then convicted and fined for possession of dangerous\ndrugs. Then in 1993 she was convicted of robbery and sentenced to 12 months\u2019\nimprisonment. At around the same time, she was convicted of a further two\ncharges of possession of dangerous drugs. In 1994 she was convicted in the\nHigh Court of 3 counts of trafficking in drugs, and sentenced to a total of 10\nyears\u2019 imprisonment.\n\n>\n\n> After her release from prison she has continued to be involved with\ndangerous drugs. She was convicted in 2002 of possession of dangerous drugs,\nand in 2005 of trafficking in dangerous drugs. For the trafficking offence she\nwas sentenced to 13 months\u2019 imprisonment. She then had convictions in 2007 for\ntheft and possession of dangerous drugs, and mostly recently in 2008 for\ntrafficking in dangerous drugs, when she was again sent to prison, this time\nfor 16 months.\n\n>\n\n> In identifying appropriate penalties when assessing an appropriate starting\npoint, I cannot ignore the defendant\u2019s criminal record. Her past offending\nreveals a failure to be deterred by the criminal justice process from\nreoffending. This failure to be deterred, this persistent reoffending, and\nthis continued involvement in drug trafficking constitutes an aggravating\nfactor justifying the adoption of a higher starting point. See HKSAR v Chan\nPui Chi [1999] 2 HKLRD 830.\n\n>\n\n> However, her counsel asks for one last chance for her client. Amongst all\nthe gloom, she points to a glimmer of hope in that the defendant did at one\nstage prior to these offences engage in some employment, and she does have a\nclose bond with her adult daughter. These two factors may provide some hope\nthat the defendant will try and break the cycle of drug addiction and drug\ntrafficking which has dogged her life.\n\n>\n\n> In the present case, the quantity of drugs is 10.90 grammes, just above the\n10 grammes lower limit of the sentencing band. I have decided to extend to the\ndefendant the last chance and the leniency that has been asked, and instead of\nincreasing the starting point within this band, I will adopt the lower limit\nof the band as my starting point. That is, 7 years. I discount her sentence by\none-third to allow for her plea of guilty.\n\n>\n\n> The resulting sentence is 4 years and 8 months, and that is the sentence I\nimpose.\n\n>\n\n> Miss Kwok, your case is one which is of great concern to me and which\ndisturbs me greatly. You have wasted your youth, and the only issue that\nremains is whether you can make something of the life that is left to you.\nYour life has been a cycle of drug addiction and drug trafficking interrupted\nby periods in prison because of these addictions. I fully appreciate that you\nmay find drug trafficking an easy means of sourcing an income, since you do\nnot have qualifications which would enable you to get a highly-paid job.\nHowever, you should be well aware that continued involvement in drug\ntrafficking can only lead to further periods of imprisonment and the\ndestruction of your life.\n\n>\n\n> You are very fortunate indeed that you still have some closeness with your\ndaughter. If you want to enjoy that relationship, then try and do something to\nbreak the cycle of drug addiction and drug trafficking. You will be well aware\nthat the Commissioner for Correctional Services has the power to reduce your\nsentence further by remitting part of it should you be of good behaviour. You\nwill also be aware of what facilities exist in prison that might enable you to\nacquire some kind of skill or qualification that you can make use of on your\nrelease.\n\n>\n\n> What you do with your life after your release is entirely in your hands. You\nare fortunate indeed that I have not started at a higher starting point than\nthe one I adopted. You can be confident that courts in future will not extend\nyou any leniency should you appear again on drug\u2011trafficking charges.\n\n>\n\n> Prison provides you with an opportunity to try and break away from drug\ntrafficking and acquire a skill. I urge you to take advantage of that\nopportunity, otherwise you will find yourself regularly appearing in court and\nregularly being sent to prison.isonment.\n\n > \n\n > After her release from prison she has continued to be involved with\ndangerous drugs.She was convicted in 2002 of possession of dangerous drugs, \nand in 2005 of trafficking in dangerous drugs.For the trafficking offence she\nwas sentenced to 13 months\u2019 imprisonment.She then had convictions in 2007 for \ntheft and possession of dangerous drugs, and mostly recently in 2008 for \ntrafficking in dangerous drugs, when she was again sent to prison, this time\nfor 16 months. "
sentences = test.replace(">", "").split("\n\n")

for sentence in sentences:

  if preprocess(sentence) == []:
    continue

  print("Original: " + sentence.replace("\n", " "))
  print(colored("Preprocessed: " + reduce(lambda x, y: x + " " + y, preprocess(sentence)), "blue"))

  curr_lowest = math.inf
  closest_aspect = None

  for aspect in lda_models:

    topic_model = lda_models[aspect]
    bow_vector = topic_model.dictionary.doc2bow(preprocess(sentence))

    if bow_vector == []:
      continue

    sorted_topics = sorted(topic_model.lda_model[bow_vector], key=lambda tup: -1*tup[1])

    # for index, score in sorted_topics:
    #   print(colored("Score: " + str(score) + "\t", "red"),
    #         colored("Topic: " + topic_model.lda_model.print_topic(index, 5), "magenta"))
      
    chosen_topic = sorted_topics[0]

    words_and_probabilities = lda_models[aspect].lda_model.get_topic_terms(0, topn=20)

    topic_weighted_vector = reduce(
        lambda v1, v2: v1 + v2,
        list(map(
            lambda wp: wp[1] * word2vec_model.wv.word_vec(lda_models[aspect].dictionary[wp[0]]),
            words_and_probabilities
        ))) / len(words_and_probabilities)

    text_weighted_vector = reduce(lambda v1, v2: v1 + v2, list(map(lambda x: word2vec_model.wv.word_vec(x) if x in word2vec_model.wv else 0, preprocess(sentence)))) / len(preprocess(sentence))

    result = spatial.distance.cosine(text_weighted_vector, topic_weighted_vector)

    print(colored(aspect + ":", "cyan"), end=" ")

    if result == 0:
      print(text_weighted_vector, topic_weighted_vector)

    if result < curr_lowest:
      curr_lowest = result
      closest_aspect = aspect
    
    print(colored(result, "blue"))

  print(closest_aspect)
# Out:
# Original: The defendant has pleaded guilty to trafficking in a dangerous drug, namely 11.14 grammes of crystalline solid containing 10.90 grammes of methamphetamine hydrochloride.
# Preprocessed: pleaded guilty grammes crystalline solid containing grammes methamphetamine hydrochloride
# offence_type_quant_of_drugs: 0.1654769778251648
# offence_role: 0.9653696306049824
# mitigating_factors_remorse: 1.0103004230186343
# mitigating_factors_self_consumption: 0.761973574757576
# mitigating_factors_characters_others: 1.1888915300369263
# background_criminal_drug_record: 0.7424896657466888
# offence_type_quant_of_drugs
# Original:  At around 1850 hours on 4 July 2011, police officers on duty outside Flat F2, 16th Floor, Kingland Apartments, No. 737‑741C Nathan Road, Mong Kok, observed the defendant exiting from this flat in a furtive manner. When the police started to approach the defendant to make inquiry of her, she immediately tried to return to her flat. One of the officers revealed his identity and then executed a search warrant of the premises.
# Preprocessed: hours july police officers duty outside flat floor kingland apartments nathan road mong kok observed exiting flat furtive manner police started approach inquiry immediately tried return flat officers revealed identity executed search warrant premises
# offence_motive: 0.9608800075948238
# offence_role: 0.7588321268558502
# aggravating_factors_commited_while_bail: 0.741960734128952
# aggravating_factors_international: 0.6503254473209381
# mitigating_factors_remorse: 1.2305305153131485
# mitigating_factors_assist_authorities: 0.528934121131897
# mitigating_factors_characters_others: 0.9704241268336773
# background_relationship_family: 0.9322091490030289
# background_criminal_drug_record: 1.146857127547264
# background_experience: 0.9342291280627251
# mitigating_factors_assist_authorities
# Original:  At around 1905 hours, when the police started to conduct the house search, the defendant told a police officer that the dangerous drugs and packaging paraphernalia were kept inside a drawer of a white cabinet near the refrigerator. Inside this drawer the police officer seized a number of items, amongst which were:
# Preprocessed: hours police started conduct house search told police officer packaging paraphernalia kept inside drawer white cabinet near refrigerator inside drawer police officer seized number items
# offence_motive: 0.9595313630998135
# offence_role: 0.6445921063423157
# aggravating_factors_commited_while_bail: 0.7995046079158783
# aggravating_factors_international: 0.8248453438282013
# mitigating_factors_remorse: 1.1608179658651352
# mitigating_factors_self_consumption: 0.9351462945342064
# mitigating_factors_assist_authorities: 0.561608076095581
# mitigating_factors_characters_others: 0.939136877655983
# background_relationship_family: 0.9627838470041752
# background_criminal_drug_record: 1.1134465634822845
# background_experience: 0.9551474787294865
# mitigating_factors_assist_authorities
# Original:  (a) eight plastic bags containing the “Ice” that is the subject of the charge;
# Preprocessed: plastic bags containing ice subject charge
# offence_type_quant_of_drugs: 0.39375579357147217
# offence_motive: 1.1237905621528625
# offence_role: 0.7976973652839661
# aggravating_factors_international: 1.1155303791165352
# aggravating_factors_other: 0.6408213973045349
# mitigating_factors_self_consumption: 0.6623664498329163
# background_criminal_drug_record: 0.8414255678653717
# offence_type_quant_of_drugs
# Original:  (b) one bundle of empty resealable transparent plastic bags;
# Preprocessed: bundle resealable transparent plastic bags
# offence_role: 0.7579809725284576
# offence_role
# Original:  (c) one electronic scale; and
# Preprocessed: electronic scale
# offence_role: 0.7580655664205551
# offence_role
# Original:  (d) one pair of scissors.
# Preprocessed: pair scissors
# None
# Original:  Between 2356 hours on 4 July 2011 and 0700 hours on 5 July 2011, the defendant was interviewed on video. Under caution she admitted the following:
# Preprocessed: hours july hours july interviewed video caution admitted following
# offence_motive: 0.9585796967148781
# offence_role: 0.7749713510274887
# background_relationship_family: 0.9467413499951363
# background_criminal_drug_record: 0.9295010566711426
# background_health: 1.1104239076375961
# offence_role
# Original:  (a) the “Ice” seized was for sale;
# Preprocessed: ice seized sale
# offence_type_quant_of_drugs: 0.36273127794265747
# offence_motive: 0.8581118881702423
# offence_role: 0.4456125497817993
# aggravating_factors_international: 0.9651731476187706
# aggravating_factors_other: 0.5512944757938385
# mitigating_factors_self_consumption: 0.29464173316955566
# background_criminal_drug_record: 0.8902143314480782
# mitigating_factors_self_consumption
# Original:  (b) the packaging paraphernalia was for packing the “Ice”; and
# Preprocessed: packaging paraphernalia packing ice
# offence_type_quant_of_drugs: 0.42778337001800537
# offence_motive: 0.8765018731355667
# offence_role: 0.5812300443649292
# aggravating_factors_international: 0.9932196135632694
# aggravating_factors_other: 0.48967862129211426
# mitigating_factors_self_consumption: 0.3679823875427246
# background_criminal_drug_record: 0.9257961362600327
# mitigating_factors_self_consumption
# Original:  (c) she rented the flat.
# Preprocessed: rented flat
# offence_role: 0.6850644052028656
# background_relationship_family: 0.8135033845901489
# offence_role
# Original:  The Government Chemist certified that the eight bags of “Ice” were 11.14 grammes of a crystalline solid containing 10.90 grammes of methamphetamine hydrochloride, a salt of methamphetamine.
# Preprocessed: government chemist certified bags ice grammes crystalline solid containing grammes methamphetamine hydrochloride salt methamphetamine
# offence_type_quant_of_drugs: 0.13245725631713867
# offence_motive: 1.2096433341503143
# offence_role: 0.827814593911171
# aggravating_factors_international: 1.0142227886244655
# aggravating_factors_other: 0.638232946395874
# mitigating_factors_self_consumption: 0.6338013112545013
# background_criminal_drug_record: 0.9393500834703445
# offence_type_quant_of_drugs
# Original:  The total retail value of the drugs seized is estimated by a police drug expert to be $7,820.
# Preprocessed: total retail value seized estimated police expert
# offence_role: 0.7446020245552063
# aggravating_factors_commited_while_bail: 0.708797425031662
# mitigating_factors_remorse: 1.1973654180765152
# mitigating_factors_self_consumption: 0.7139316201210022
# mitigating_factors_assist_authorities: 0.8008528649806976
# mitigating_factors_characters_others: 0.9982524731894955
# background_criminal_drug_record: 0.8974178284406662
# aggravating_factors_commited_while_bail
# Original:  In a number of different cases the Hong Kong Court of Appeal has set out the principles and sentencing guidelines for judges to follow when sentencing a defendant convicted of a drug trafficking offence.
# Preprocessed: number different cases court appeal set principles sentencing guidelines judges follow sentencing convicted
# offence_role: 1.139146089553833
# aggravating_factors_commited_while_bail: 0.8979693874716759
# aggravating_factors_persistence: 0.6834320425987244
# aggravating_factors_other: 0.5416481196880341
# mitigating_factors_remorse: 1.0458889417350292
# mitigating_factors_self_consumption: 0.8936629518866539
# mitigating_factors_characters_others: 0.9193894267082214
# background_relationship_family: 1.1117750778794289
# background_criminal_drug_record: 0.6993007361888885
# background_health: 1.0494692772626877
# aggravating_factors_other
# Original:  The first is that the sentencing ranges for trafficking in “Ice” are to be taken from the guidelines laid down by the Court of Appeal in Attorney-General and Ching Kwok Hung [1991] 2 HKLRD 125as amended by the Court of Appeal in the subsequent decision of HKSAR v Capitania CACC28/2004. As a result of this subsequent amendment the first sentencing band relates to quantities up to 10 grammes and so in the present case, as the quantity in which this defendant trafficked was 10.90 grammes of “Ice”, this defendant is placed in the 7 to 10 years band for sentencing purposes.
# Preprocessed: sentencing ranges ice taken guidelines laid court appeal attorney general ching kwok hung hklrd amended court appeal subsequent decision hksar capitania cacc result subsequent amendment sentencing band relates quantities grammes present case quantity trafficked grammes ice placed years band sentencing purposes
# offence_type_quant_of_drugs: 0.39467597007751465
# offence_motive: 1.2370742112398148
# offence_role: 1.064097374677658
# aggravating_factors_commited_while_bail: 0.8247742503881454
# aggravating_factors_persistence: 0.8356546759605408
# aggravating_factors_international: 0.8546144068241119
# aggravating_factors_other: 0.4970499277114868
# mitigating_factors_remorse: 1.1287737339735031
# mitigating_factors_self_consumption: 0.8032802194356918
# mitigating_factors_assist_authorities: 1.2293863743543625
# mitigating_factors_characters_others: 1.125284418463707
# background_relationship_family: 1.1814771443605423
# background_criminal_drug_record: 0.8295785635709763
# background_health: 1.205196276307106
# background_experience: 1.043117430061102
# offence_type_quant_of_drugs
# Original:  The existence of these sentencing tariffs leaves little room for mitigation, but notwithstanding this, the sentencing tariffs play a very important role for two main reasons. Firstly, they lead to consistency in sentencing and avoid distinctions being drawn between drug traffickers based upon the nature of their trafficking, whether they be couriers, storekeepers, or play some other role. Whatever the role played by the trafficker, the sentence will generally be the same. See HKSAR v Manalo [2001] 1 HKLRD 557 at 560 G-H.
# Preprocessed: existence sentencing tariffs leaves little room mitigation notwithstanding sentencing tariffs play important role main reasons firstly lead consistency sentencing avoid distinctions drawn traffickers based nature couriers storekeepers play role role played trafficker sentence generally hksar manalo hklrd
# offence_motive: 1.0322704389691353
# offence_role: 1.1214188933372498
# aggravating_factors_persistence: 0.8408083617687225
# aggravating_factors_other: 0.4040970802307129
# mitigating_factors_self_consumption: 0.6916956901550293
# mitigating_factors_characters_others: 0.8301597088575363
# background_relationship_family: 1.1038775891065598
# background_criminal_drug_record: 0.8462410867214203
# aggravating_factors_other
# Original:  The purpose of these sentencing bands is to lead to consistency in sentencing, and secondly, to deter those who might otherwise be tempted by what they perceive as an easy and low‑risk means to substantial profits. See Secretary for Justice v Chan Ka Wah [2005] 4 HKLR 904 at 908, paragraph 20.
# Preprocessed: purpose sentencing bands lead consistency sentencing secondly deter tempted perceive easy low risk means substantial profits secretary justice chan wah hklr paragraph
# offence_motive: 0.8922140747308731
# offence_role: 0.8987986221909523
# aggravating_factors_other: 0.47803622484207153
# background_criminal_drug_record: 1.0530080571770668
# aggravating_factors_other
# Original:  The Court of Appeal has made it clear that it requires exceptional circumstances to justify a departure from the guidelines, and that whilst a sentencing judge may retain some degree of discretion, the sentence imposed should normally be within the suggested bands. See the Chan Ka Wah case at page 908, paragraph 22.
# Preprocessed: court appeal clear requires exceptional circumstances justify departure guidelines sentencing judge retain degree discretion sentence imposed normally suggested bands chan wah case page paragraph
# offence_motive: 1.1420364379882812
# offence_role: 1.2797677516937256
# aggravating_factors_commited_while_bail: 0.8062517642974854
# aggravating_factors_persistence: 0.8175999522209167
# aggravating_factors_international: 0.8443427085876465
# aggravating_factors_other: 0.5882105231285095
# mitigating_factors_remorse: 0.9419619292020798
# mitigating_factors_self_consumption: 0.9583399556577206
# mitigating_factors_assist_authorities: 1.0381170511245728
# mitigating_factors_characters_others: 0.8777597770094872
# background_relationship_family: 1.107352614402771
# background_criminal_drug_record: 0.8883202970027924
# background_experience: 1.133054330945015
# aggravating_factors_other
# Original:  No such circumstances are present in this case. Nevertheless, I still have some sentencing discretion, and I can take into account the amount of packets, the type of mixture containing the narcotic, the degree of the involvement of the offender and any previous involvement he or she may have had in drug offences. See HKSAR v Abdallah [2009] 2 HKLRD 437 and HKSAR v Chong Heung Sang [2010] 3 HKC 88.
# Preprocessed: circumstances present case sentencing discretion account packets type mixture containing narcotic degree involvement offender previous involvement offences hksar abdallah hklrd hksar chong heung sang hkc
# offence_type_quant_of_drugs: 0.5764949917793274
# offence_motive: 1.2224008738994598
# offence_role: 1.1853106021881104
# aggravating_factors_commited_while_bail: 0.7340174913406372
# aggravating_factors_persistence: 0.6570190787315369
# aggravating_factors_international: 0.9049281477928162
# aggravating_factors_other: 0.43162429332733154
# mitigating_factors_self_consumption: 0.8772631362080574
# mitigating_factors_assist_authorities: 1.1952145397663116
# mitigating_factors_characters_others: 0.98394725471735
# background_relationship_family: 1.168690800666809
# background_criminal_drug_record: 0.6248739957809448
# background_experience: 1.0884042009711266
# aggravating_factors_other
# Original:  The defendant is 40 years of age and has received education only up to secondary Form 1 level. She was unemployed at the time of her arrest. She is single, and lived alone. She claims to have been addicted to “Ice” for the past 10 years.
# Preprocessed: years age received education secondary form level unemployed time arrest single lived claims addicted ice past years
# offence_type_quant_of_drugs: 0.6515419185161591
# offence_motive: 0.6889864206314087
# offence_role: 0.8108172863721848
# aggravating_factors_persistence: 0.4843605160713196
# aggravating_factors_international: 0.9020995274186134
# aggravating_factors_other: 0.8623012900352478
# mitigating_factors_self_consumption: 0.9331680312752724
# mitigating_factors_characters_others: 0.5718790590763092
# background_relationship_family: 0.4220067262649536
# background_criminal_drug_record: 0.545610636472702
# background_health: 0.65227872133255
# background_experience: 0.1756807565689087
# background_experience
# Original:  She has a criminal record dating back to 1989, when she would have been only 18 years of age. She was then convicted and fined for possession of dangerous drugs. Then in 1993 she was convicted of robbery and sentenced to 12 months’ imprisonment. At around the same time, she was convicted of a further two charges of possession of dangerous drugs. In 1994 she was convicted in the High Court of 3 counts of trafficking in drugs, and sentenced to a total of 10 years’ imprisonment.
# Preprocessed: criminal record dating years age convicted fined possession convicted robbery sentenced months imprisonment time convicted charges possession convicted high court counts sentenced total years imprisonment
# offence_motive: 1.0376974754035473
# offence_role: 1.0526940636336803
# aggravating_factors_commited_while_bail: 0.8130821734666824
# aggravating_factors_persistence: 0.2235206961631775
# aggravating_factors_other: 0.6555088460445404
# mitigating_factors_remorse: 0.8967752084136009
# mitigating_factors_self_consumption: 0.9125626012682915
# mitigating_factors_characters_others: 0.8285844624042511
# background_relationship_family: 0.8500638157129288
# background_criminal_drug_record: 0.22658896446228027
# background_health: 1.0685387030243874
# background_experience: 0.8339050114154816
# aggravating_factors_persistence
# Original:  After her release from prison she has continued to be involved with dangerous drugs. She was convicted in 2002 of possession of dangerous drugs, and in 2005 of trafficking in dangerous drugs. For the trafficking offence she was sentenced to 13 months’ imprisonment. She then had convictions in 2007 for theft and possession of dangerous drugs, and mostly recently in 2008 for trafficking in dangerous drugs, when she was again sent to prison, this time for 16 months.
# Preprocessed: release prison continued involved convicted possession sentenced months imprisonment convictions theft possession recently sent prison time months
# offence_motive: 0.8050158768892288
# offence_role: 0.9171383753418922
# aggravating_factors_persistence: 0.21069252490997314
# aggravating_factors_international: 0.9198587536811829
# aggravating_factors_other: 0.6952174305915833
# mitigating_factors_self_consumption: 0.8511159271001816
# mitigating_factors_characters_others: 0.7560961246490479
# background_relationship_family: 0.7772685885429382
# background_criminal_drug_record: 0.21925300359725952
# background_health: 0.8702746629714966
# background_experience: 0.7717152535915375
# aggravating_factors_persistence
# Original:  In identifying appropriate penalties when assessing an appropriate starting point, I cannot ignore the defendant’s criminal record. Her past offending reveals a failure to be deterred by the criminal justice process from reoffending. This failure to be deterred, this persistent reoffending, and this continued involvement in drug trafficking constitutes an aggravating factor justifying the adoption of a higher starting point. See HKSAR v Chan Pui Chi [1999] 2 HKLRD 830.
# Preprocessed: identifying appropriate penalties assessing appropriate starting point ignore criminal record past offending reveals failure deterred criminal justice process reoffending failure deterred persistent reoffending continued involvement constitutes aggravating factor justifying adoption higher starting point hksar chan pui chi hklrd
# offence_role: 1.2352937757968903
# aggravating_factors_persistence: 0.6645394563674927
# aggravating_factors_international: 0.6869831085205078
# aggravating_factors_other: 0.5267730355262756
# mitigating_factors_characters_others: 0.9083826914429665
# background_relationship_family: 1.0707363784313202
# background_criminal_drug_record: 0.6858888566493988
# aggravating_factors_other
# Original:  However, her counsel asks for one last chance for her client. Amongst all the gloom, she points to a glimmer of hope in that the defendant did at one stage prior to these offences engage in some employment, and she does have a close bond with her adult daughter. These two factors may provide some hope that the defendant will try and break the cycle of drug addiction and drug trafficking which has dogged her life.
# Preprocessed: counsel asks chance client gloom points glimmer hope stage prior offences engage employment close bond adult daughter factors provide hope try break cycle addiction dogged life
# offence_motive: 0.5130713284015656
# aggravating_factors_commited_while_bail: 0.9280672818422318
# aggravating_factors_persistence: 0.6176000237464905
# mitigating_factors_self_consumption: 0.9356570690870285
# mitigating_factors_characters_others: 0.4253469705581665
# background_relationship_family: 0.44117122888565063
# background_criminal_drug_record: 0.6918080747127533
# background_experience: 0.7725593894720078
# mitigating_factors_characters_others
# Original:  In the present case, the quantity of drugs is 10.90 grammes, just above the 10 grammes lower limit of the sentencing band. I have decided to extend to the defendant the last chance and the leniency that has been asked, and instead of increasing the starting point within this band, I will adopt the lower limit of the band as my starting point. That is, 7 years. I discount her sentence by one-third to allow for her plea of guilty.
# Preprocessed: present case quantity grammes grammes lower limit sentencing band decided extend chance leniency asked instead increasing starting point band adopt lower limit band starting point years discount sentence allow plea guilty
# offence_type_quant_of_drugs: 0.44755876064300537
# offence_motive: 1.088742807507515
# offence_role: 1.0545646771788597
# aggravating_factors_commited_while_bail: 0.8411215245723724
# aggravating_factors_persistence: 0.7551030218601227
# aggravating_factors_international: 0.7845256179571152
# aggravating_factors_other: 0.44058746099472046
# mitigating_factors_remorse: 0.9195641651749611
# mitigating_factors_self_consumption: 0.6269365847110748
# mitigating_factors_assist_authorities: 1.0697486624121666
# mitigating_factors_characters_others: 1.0045367502607405
# background_relationship_family: 1.040154505521059
# background_criminal_drug_record: 0.8099814653396606
# background_health: 1.1872623413801193
# background_experience: 1.056094914674759
# aggravating_factors_other
# Original:  The resulting sentence is 4 years and 8 months, and that is the sentence I impose.
# Preprocessed: resulting sentence years months sentence impose
# offence_motive: 1.0507731884717941
# aggravating_factors_persistence: 0.5641263127326965
# aggravating_factors_other: 0.5824775993824005
# mitigating_factors_characters_others: 0.9668406471610069
# background_relationship_family: 0.9520317055284977
# background_criminal_drug_record: 0.6304153800010681
# background_health: 1.0716901421546936
# background_experience: 1.0575032010674477
# aggravating_factors_persistence
# Original:  Miss Kwok, your case is one which is of great concern to me and which disturbs me greatly. You have wasted your youth, and the only issue that remains is whether you can make something of the life that is left to you. Your life has been a cycle of drug addiction and drug trafficking interrupted by periods in prison because of these addictions. I fully appreciate that you may find drug trafficking an easy means of sourcing an income, since you do not have qualifications which would enable you to get a highly-paid job. However, you should be well aware that continued involvement in drug trafficking can only lead to further periods of imprisonment and the destruction of your life.
# Preprocessed: miss kwok case great concern disturbs greatly wasted youth issue remains life left life cycle addiction interrupted periods prison addictions fully appreciate easy means sourcing income qualifications enable highly paid job aware continued involvement lead periods imprisonment destruction life
# offence_motive: 0.4462032914161682
# offence_role: 0.8880940824747086
# aggravating_factors_commited_while_bail: 1.0653440356254578
# aggravating_factors_persistence: 0.6502413153648376
# aggravating_factors_international: 0.9072295650839806
# mitigating_factors_remorse: 0.528519332408905
# mitigating_factors_self_consumption: 0.9040509164333344
# mitigating_factors_assist_authorities: 0.9028546139597893
# mitigating_factors_characters_others: 0.44346755743026733
# background_relationship_family: 0.44644951820373535
# background_criminal_drug_record: 0.7128055393695831
# background_health: 0.37425923347473145
# background_experience: 0.6358908414840698
# background_health
# Original:  You are very fortunate indeed that you still have some closeness with your daughter. If you want to enjoy that relationship, then try and do something to break the cycle of drug addiction and drug trafficking. You will be well aware that the Commissioner for Correctional Services has the power to reduce your sentence further by remitting part of it should you be of good behaviour. You will also be aware of what facilities exist in prison that might enable you to acquire some kind of skill or qualification that you can make use of on your release.
# Preprocessed: fortunate closeness daughter want enjoy relationship try break cycle addiction aware commissioner correctional services power reduce sentence remitting good behaviour aware facilities exist prison enable acquire kind skill qualification use release
# offence_motive: 0.4785725474357605
# offence_role: 0.9104596450924873
# aggravating_factors_persistence: 0.67746502161026
# aggravating_factors_other: 0.9286781474947929
# mitigating_factors_self_consumption: 0.83915875852108
# mitigating_factors_characters_others: 0.43391770124435425
# background_relationship_family: 0.5287908017635345
# background_criminal_drug_record: 0.7381087839603424
# background_personality: 0.46126705408096313
# background_health: 0.3000801205635071
# background_health
# Original:  What you do with your life after your release is entirely in your hands. You are fortunate indeed that I have not started at a higher starting point than the one I adopted. You can be confident that courts in future will not extend you any leniency should you appear again on drug‑trafficking charges.
# Preprocessed: life release entirely hands fortunate started higher starting point adopted confident courts future extend leniency appear charges
# offence_motive: 0.8160395324230194
# offence_role: 1.0492359809577465
# aggravating_factors_international: 0.7817707657814026
# mitigating_factors_characters_others: 0.7488429248332977
# background_relationship_family: 0.7701025307178497
# background_criminal_drug_record: 0.7715210169553757
# background_experience: 0.8839475959539413
# mitigating_factors_characters_others
# Original:  Prison provides you with an opportunity to try and break away from drug trafficking and acquire a skill. I urge you to take advantage of that opportunity, otherwise you will find yourself regularly appearing in court and regularly being sent to prison.isonment.
# Preprocessed: prison provides opportunity try break away acquire skill urge advantage opportunity regularly appearing court regularly sent prison isonment
# offence_motive: 0.5746957957744598
# aggravating_factors_commited_while_bail: 0.8304973393678665
# aggravating_factors_persistence: 0.6015349328517914
# aggravating_factors_international: 0.8699985593557358
# aggravating_factors_other: 1.08809382468462
# mitigating_factors_remorse: 0.6078757643699646
# mitigating_factors_self_consumption: 1.1521411091089249
# mitigating_factors_characters_others: 0.572595626115799
# background_relationship_family: 0.519097626209259
# background_criminal_drug_record: 0.7330796718597412
# background_relationship_family
# Original:   After her release from prison she has continued to be involved with dangerous drugs.She was convicted in 2002 of possession of dangerous drugs,  and in 2005 of trafficking in dangerous drugs.For the trafficking offence she was sentenced to 13 months’ imprisonment.She then had convictions in 2007 for  theft and possession of dangerous drugs, and mostly recently in 2008 for  trafficking in dangerous drugs, when she was again sent to prison, this time for 16 months.
# Preprocessed: release prison continued involved convicted possession sentenced months imprisonment convictions theft possession recently sent prison time months
# offence_motive: 0.8050158768892288
# offence_role: 0.9171383753418922
# aggravating_factors_persistence: 0.21069252490997314
# aggravating_factors_international: 0.9198587536811829
# aggravating_factors_other: 0.6952174305915833
# mitigating_factors_self_consumption: 0.8511159271001816
# mitigating_factors_characters_others: 0.7560961246490479
# background_relationship_family: 0.7772685885429382
# background_criminal_drug_record: 0.21925300359725952
# background_health: 0.8702746629714966
# background_experience: 0.7717152535915375
# aggravating_factors_persistence

# %%
text = """

The defendant has pleaded guilty to trafficking in a dangerous drug, namely 11.14 grammes of crystalline solid containing 10.90 grammes of methamphetamine hydrochloride.

At around 1850 hours on 4 July 2011, police officers on duty outside Flat F2,  16th Floor, Kingland Apartments , No. 737‑741C Nathan Road, Mong Kok, observed the defendant exiting from this flat in a furtive manner. When the police started to approach the defendant to make inquiry of her, she immediately tried to return to her flat. One of the officers revealed his identity and then executed a search warrant of the premises.

At around 1905 hours, when the police started to conduct the house search, the defendant told a police officer that the dangerous drugs and packaging paraphernalia were kept inside a drawer of a white cabinet near the refrigerator. Inside this drawer the police officer seized a number of items, amongst which were:

(a) eight plastic bags containing the “Ice” that is the subject of the charge;

(b) one bundle of empty resealable transparent plastic bags;

(c) one electronic scale; and

(d) one pair of scissors.

Between 2356 hours on 4 July 2011 and 0700 hours on 5 July 2011, the defendant was interviewed on video. Under caution she admitted the following:

(a) the “Ice” seized was for sale;

(b) the packaging paraphernalia was for packing the “Ice”; and

(c) she rented the flat.

The Government Chemist certified that the eight bags of “Ice” were 11.14 grammes of a crystalline solid containing 10.90 grammes of methamphetamine hydrochloride, a salt of methamphetamine.

The total retail value of the drugs seized is estimated by a police drug expert to be $7,820.

In a number of different cases the Hong Kong Court of Appeal has set out the principles and sentencing guidelines for judges to follow when sentencing a defendant convicted of a drug trafficking offence.

The first is that the sentencing ranges for trafficking in “Ice” are to be taken from the guidelines laid down by the Court of Appeal in Attorney-General and Ching Kwok Hung [1991] 2 HKLRD 125as amended by the Court of Appeal in the subsequent decision of HKSAR v Capitania CACC28/2004. As a result of this subsequent amendment the first sentencing band relates to quantities up to 10 grammes and so in the present case, as the quantity in which this defendant trafficked was 10.90 grammes of “Ice”, this defendant is placed in the 7 to 10 years band for sentencing purposes.

The existence of these sentencing tariffs leaves little room for mitigation, but notwithstanding this, the sentencing tariffs play a very important role for two main reasons. Firstly, they lead to consistency in sentencing and avoid distinctions being drawn between drug traffickers based upon the nature of their trafficking, whether they be couriers, storekeepers, or play some other role. Whatever the role played by the trafficker, the sentence will generally be the same. See HKSAR v Manalo [2001] 1 HKLRD 557 at 560 G-H.

The purpose of these sentencing bands is to lead to consistency in sentencing, and secondly, to deter those who might otherwise be tempted by what they perceive as an easy and low‑risk means to substantial profits. See Secretary for Justice v Chan Ka Wah [2005] 4 HKLR 904 at 908, paragraph 20.

The Court of Appeal has made it clear that it requires exceptional circumstances to justify a departure from the guidelines, and that whilst a sentencing judge may retain some degree of discretion, the sentence imposed should normally be within the suggested bands. See the Chan Ka Wah case at page 908, paragraph 22.

No such circumstances are present in this case. Nevertheless, I still have some sentencing discretion, and I can take into account the amount of packets, the type of mixture containing the narcotic, the degree of the involvement of the offender and any previous involvement he or she may have had in drug offences. See HKSAR v Abdallah [2009] 2 HKLRD 437 and HKSAR v Chong Heung Sang [2010] 3 HKC 88.

The defendant is 40 years of age and has received education only up to secondary Form 1 level. She was unemployed at the time of her arrest. She is single, and lived alone. She claims to have been addicted to “Ice” for the past 10 years.

She has a criminal record dating back to 1989, when she would have been only 18 years of age. She was then convicted and fined for possession of dangerous drugs. Then in 1993 she was convicted of robbery and sentenced to 12 months’ imprisonment. At around the same time, she was convicted of a further two charges of possession of dangerous drugs. In 1994 she was convicted in the High Court of 3 counts of trafficking in drugs, and sentenced to a total of 10 years’ imprisonment.

After her release from prison she has continued to be involved with dangerous drugs. She was convicted in 2002 of possession of dangerous drugs, and in 2005 of trafficking in dangerous drugs. For the trafficking offence she was sentenced to 13 months’ imprisonment. She then had convictions in 2007 for theft and possession of dangerous drugs, and mostly recently in 2008 for trafficking in dangerous drugs, when she was again sent to prison, this time for 16 months.

In identifying appropriate penalties when assessing an appropriate starting point, I cannot ignore the defendant’s criminal record. Her past offending reveals a failure to be deterred by the criminal justice process from reoffending. This failure to be deterred, this persistent reoffending, and this continued involvement in drug trafficking constitutes an aggravating factor justifying the adoption of a higher starting point. See HKSAR v Chan Pui Chi [1999] 2 HKLRD 830.

However, her counsel asks for one last chance for her client. Amongst all the gloom, she points to a glimmer of hope in that the defendant did at one stage prior to these offences engage in some employment, and she does have a close bond with her adult daughter. These two factors may provide some hope that the defendant will try and break the cycle of drug addiction and drug trafficking which has dogged her life.

In the present case, the quantity of drugs is 10.90 grammes, just above the 10 grammes lower limit of the sentencing band. I have decided to extend to the defendant the last chance and the leniency that has been asked, and instead of increasing the starting point within this band, I will adopt the lower limit of the band as my starting point. That is, 7 years. I discount her sentence by one-third to allow for her plea of guilty.

The resulting sentence is 4 years and 8 months, and that is the sentence I impose.

Miss Kwok, your case is one which is of great concern to me and which disturbs me greatly. You have wasted your youth, and the only issue that remains is whether you can make something of the life that is left to you. Your life has been a cycle of drug addiction and drug trafficking interrupted by periods in prison because of these addictions. I fully appreciate that you may find drug trafficking an easy means of sourcing an income, since you do not have qualifications which would enable you to get a highly-paid job. However, you should be well aware that continued involvement in drug trafficking can only lead to further periods of imprisonment and the destruction of your life.

You are very fortunate indeed that you still have some closeness with your daughter. If you want to enjoy that relationship, then try and do something to break the cycle of drug addiction and drug trafficking. You will be well aware that the Commissioner for Correctional Services has the power to reduce your sentence further by remitting part of it should you be of good behaviour. You will also be aware of what facilities exist in prison that might enable you to acquire some kind of skill or qualification that you can make use of on your release.

What you do with your life after your release is entirely in your hands. You are fortunate indeed that I have not started at a higher starting point than the one I adopted. You can be confident that courts in future will not extend you any leniency should you appear again on drug‑trafficking charges.

Prison provides you with an opportunity to try and break away from drug trafficking and acquire a skill. I urge you to take advantage of that opportunity, otherwise you will find yourself regularly appearing in court and regularly being sent to prison.

"""

# %%
# word2vec_model.wv.most_similar("years of imprisonment")
5 * word2vec_model.wv.word_vec("imprisonment") + 3 * word2vec_model.wv.word_vec("skill")
# Out:
# array([ -9.462629  , -18.404139  ,  -8.426258  ,  -0.99144614,
#         -3.1612248 ,   6.6138897 ,   3.4411068 ,  10.961947  ,
#          7.574908  ,  -9.069915  ,   0.59963787,  -7.169389  ,
#         12.39362   ,   1.995619  ,   4.3024845 ,   5.582766  ,
#          4.411383  ,   3.4278934 ,   7.966709  , -10.625965  ,
#        -26.951757  ,  19.978394  ,  -6.6005497 ,  -2.9069376 ,
#        -11.899344  ,  -1.0757685 ,  -0.84889686, -12.8987465 ,
#        -10.787942  ,   0.3023861 ,   6.3125176 ,  12.784238  ,
#         -0.2117269 ,   3.19437   , -10.850562  ,   3.41884   ,
#          4.4756026 ,  -5.5148163 , -14.053297  ,  -1.9419237 ,
#          4.745144  ,  -0.54399425,   3.5719552 ,  10.0396185 ,
#         -6.497223  ,  -3.7446046 ,   9.462566  ,  -0.90779823,
#         -0.9959442 ,  -2.9331176 ,  11.473785  ,   1.0496285 ,
#        -15.681624  , -11.269348  ,   5.7783475 ,   0.10609275,
#          2.212152  ,  -4.375989  ,   2.6229682 ,   6.8963447 ,
#          5.2809253 , -12.947457  , -11.770961  ,   5.207824  ,
#          9.446082  ,  -2.0995812 ,   4.9964137 ,  -7.3545017 ,
#         -2.2371016 ,  12.705546  ,   0.49163407, -25.125296  ,
#         -3.648912  ,   1.1052566 ,  -2.8872986 ,  10.622965  ,
#         -5.849306  ,  -3.2784941 ,   0.7265551 , -10.732568  ,
#        -13.922245  ,  -4.5707498 ,  -7.3740563 ,  -1.9327242 ,
#         -2.4844806 ,   7.167224  ,  10.07778   ,  -3.0654252 ,
#         -5.952231  ,  -0.27471524,   4.6138096 ,  -7.032954  ,
#         13.343707  ,  11.825249  ,  -8.721364  ,  -9.704639  ,
#         -4.631596  ,  -8.756473  , -18.090366  ,   4.242183  ],
#       dtype=float32)

# %%
text = "The defendant has pleaded guilty to trafficking in a dangerous drug, namely 11.14 grammes of crystalline solid containing 10.90 grammes of methamphetamine hydrochloride."




# print(lda_models["offence_motive"].lda_model.get_topic_terms(0, topn=20))

# print(lda_models["offence_motive"].dictionary[10])

# print(list(map(lambda x: x[0], lda_models["offence_motive"].dictionary.doc2bow(["committed", "family"]))))
# Out:
# [-0.7037809  -1.4865761   0.96001655  0.74256635  0.02258958  0.09871833
#   2.5635993   2.237731   -0.22575304 -1.3240633   0.63807815  1.1514897
#   0.94312835 -1.3376623   0.50615644 -1.0943182   0.27222097  2.741008
#   0.70129085 -2.1133573  -1.2169962   1.6650866  -1.4835291   0.19273236
#   0.48846966 -1.0365473   0.5379564  -0.5187251   0.64966434  1.686719
#   2.0091708   0.43115664 -0.00381713 -0.54823405 -0.15451986  1.1908305
#  -0.28028634 -0.12362666 -0.65262246 -2.3809776   0.16119276  0.34824502
#   1.7731658   0.36839    -0.93991536 -0.3077803  -0.05061044 -0.56036174
#  -0.1441168   0.57661873  1.0668329   0.67739904  0.13642591 -0.64004487
#  -0.08782891  0.04519963  0.99354297 -1.7364101  -0.6636822  -1.458984
#   0.6552676  -1.5719066   0.3127681   0.589803   -0.14864776 -1.4916607
#   0.27721587 -1.3904781  -0.60537875 -0.42147553  0.75302243 -1.0442442
#   0.09257434 -2.0778825  -0.3179809   1.2230405   0.18583694  0.20629078
#   1.7416749  -0.68807846 -2.413048    0.7026432  -1.5527589   1.1669315
#   0.19657853 -0.09791814 -1.0614524  -0.4507221  -0.65337956  0.90567505
#   0.78912693  0.0182639   1.2255307   1.6372015   0.5531526  -0.43482706
#   0.0461712   1.4554275  -0.7278306   0.2285716 ] [ 1.0399232e-02  2.0908978e-02  8.1176478e-03  2.0223688e-02
#   7.5320224e-04  8.8868579e-03  1.2413965e-02 -9.2422627e-03
#   1.7165180e-02 -7.5313919e-03 -5.5714021e-03 -2.4627078e-02
#   1.6979339e-02  1.0606306e-02 -2.0426927e-02  1.3428780e-02
#  -4.1740816e-04 -4.4483982e-02 -9.3841245e-03  4.0450700e-02
#  -6.5153190e-03  1.3510130e-02  3.9356309e-03 -2.5436705e-02
#  -1.9806318e-02 -1.4214580e-02  3.4294897e-03 -9.8958369e-03
#   2.1943836e-02  1.1999717e-02  3.7409265e-03  1.8165974e-02
#   6.4565078e-03 -2.7188029e-02  3.5012975e-02 -2.0519746e-02
#   1.2376035e-02  1.2451431e-02  2.5860318e-03  3.0308929e-03
#   8.4142936e-03 -2.5718143e-02  1.8392352e-03 -2.2726905e-02
#   4.1894699e-03 -2.7156603e-02  2.3525725e-03  2.5035506e-03
#  -7.2486647e-03 -1.6858563e-04  1.5819445e-03  1.8062811e-02
#  -1.0073182e-02 -2.7210150e-02 -4.5058923e-03  1.0996860e-02
#  -3.0358324e-02  3.7846416e-03  1.6906569e-02  6.5564178e-03
#  -2.9273659e-02  2.5983933e-02 -2.9136200e-04 -2.1934383e-02
#  -2.3601076e-02 -4.2333012e-03  2.2735439e-02 -8.6963279e-03
#  -7.7441484e-03  1.1801560e-02 -4.5804981e-02  3.0860031e-02
#   2.2359233e-02  3.3134647e-02 -2.3182412e-03 -7.8714546e-03
#   2.3879590e-03 -9.4296057e-03  1.2013928e-02 -3.3343532e-03
#   7.1777874e-03  5.5580367e-03  1.7475199e-02  2.8674874e-02
#  -2.7015734e-02  3.5843652e-02  3.1053120e-02  7.4337339e-03
#  -9.9014975e-03  1.5949068e-05  3.4406427e-03  7.9133324e-03
#   1.9232728e-02  1.5037996e-02  2.2502292e-02 -3.2104454e-03
#   1.3947678e-02  3.9067129e-03  3.2019552e-03 -4.9425890e-03]
# 1.2093196511268616
